# %%
import json

# %%
def load_data():
    with open("patients.json", "r") as f:
        data = json.load(f)
    return data

# %%
data = load_data()

# %%
data
# Out:
# {'P001': {'name': 'Ananya Verma',
#   'city': 'Guwahati',
#   'age': 28,
#   'gender': 'female',
#   'height': 1.65,
#   'weight': 90.0,
#   'bmi': 33.06,
#   'verdict': 'Obese'},
#  'P002': {'name': 'Ravi Mehta',
#   'city': 'Mumbai',
#   'age': 35,
#   'gender': 'male',
#   'height': 1.75,
#   'weight': 85,
#   'bmi': 27.76,
#   'verdict': 'Overweight'},
#  'P003': {'name': 'Sneha Kulkarni',
#   'city': 'Pune',
#   'age': 22,
#   'gender': 'female',
#   'height': 1.6,
#   'weight': 45,
#   'bmi': 17.58,
#   'verdict': 'Underweight'},
#  'P004': {'name': 'Arjun Verma',
#   'city': 'Mumbai',
#   'age': 40,
#   'gender': 'male',
#   'height': 1.8,
#   'weight': 90.0,
#   'bmi': 27.78,
#   'verdict': 'Normal'},
#  'P005': {'name': 'Neha Sinha',
#   'city': 'Kolkata',
#   'age': 30,
#   'gender': 'female',
#   'height': 1.55,
#   'weight': 75,
#   'bmi': 31.22,
#   'verdict': 'Obese'}}

# %%
sorted(data.items(), key=lambda x: data[x]['name'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 sorted(data.items(), key=lambda x: data[x]['name'])
#
# Cell In[16], line 1, in <lambda>(x)
# ----> 1 sorted(data.items(), key=lambda x: data[x]['name'])
#
# TypeError: unhashable type: 'dict'

# %%
data.values()
# Out:
# dict_values([{'name': 'Ananya Verma', 'city': 'Guwahati', 'age': 28, 'gender': 'female', 'height': 1.65, 'weight': 90.0, 'bmi': 33.06, 'verdict': 'Obese'}, {'name': 'Ravi Mehta', 'city': 'Mumbai', 'age': 35, 'gender': 'male', 'height': 1.75, 'weight': 85, 'bmi': 27.76, 'verdict': 'Overweight'}, {'name': 'Sneha Kulkarni', 'city': 'Pune', 'age': 22, 'gender': 'female', 'height': 1.6, 'weight': 45, 'bmi': 17.58, 'verdict': 'Underweight'}, {'name': 'Arjun Verma', 'city': 'Mumbai', 'age': 40, 'gender': 'male', 'height': 1.8, 'weight': 90.0, 'bmi': 27.78, 'verdict': 'Normal'}, {'name': 'Neha Sinha', 'city': 'Kolkata', 'age': 30, 'gender': 'female', 'height': 1.55, 'weight': 75, 'bmi': 31.22, 'verdict': 'Obese'}])
